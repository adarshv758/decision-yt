# %%
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("station_data_dataverse.csv")

# %%
df
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 0       1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1       3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2       4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3       3173284      6.17     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4       3266500      0.93     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
# ...         ...       ...      ...                  ...                  ...
# 3390    7021565      6.74     0.00  0015-10-01 16:31:18  0015-10-01 19:59:08
# 3391    3758092      6.86     0.00  0015-10-02 16:28:48  0015-10-02 19:27:05
# 3392    5858374      6.07     0.00  0015-09-30 16:54:22  0015-09-30 20:24:06
# 3393    2586645      5.74     0.00  0015-09-24 11:43:02  0015-09-24 13:55:12
# 3394    7860608      6.95     0.00  0015-10-01 16:43:05  0015-10-01 19:42:06
#
#       startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 0            15       17       1.510556     Tue  android  ...               0
# 1            17       19       2.177222     Wed  android  ...               0
# 2            12       16       4.671667     Fri  android  ...               0
# 3            19       21       1.768333     Wed  android  ...               0
# 4            20       21       0.298611     Thu  android  ...               0
# ...         ...      ...            ...     ...      ...  ...             ...
# 3390         16       19       3.463889     Thu      ios  ...               0
# 3391         16       19       2.971389     Fri      ios  ...               0
# 3392         16       20       3.495556     Wed  android  ...               0
# 3393         11       13       2.202778     Thu      ios  ...               1
# 3394         16       19       2.983611     Thu      ios  ...               0
#
#       facilityType  Mon  Tues  Wed  Thurs  Fri  Sat  Sun  reportedZip
# 0                3    0     1    0      0    0    0    0            0
# 1                3    0     0    1      0    0    0    0            0
# 2                3    0     0    0      0    1    0    0            0
# 3                3    0     0    1      0    0    0    0            0
# 4                3    0     0    0      1    0    0    0            0
# ...            ...  ...   ...  ...    ...  ...  ...  ...          ...
# 3390             2    0     0    0      1    0    0    0            1
# 3391             2    0     0    0      0    1    0    0            1
# 3392             3    0     0    1      0    0    0    0            1
# 3393             2    0     0    0      1    0    0    0            1
# 3394             3    0     0    0      1    0    0    0            1
#
# [3395 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['sessionId', 'kwhTotal', 'dollars', 'created', 'ended', 'startTime',
#        'endTime', 'chargeTimeHrs', 'weekday', 'platform', 'distance', 'userId',
#        'stationId', 'locationId', 'managerVehicle', 'facilityType', 'Mon',
#        'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun', 'reportedZip'],
#       dtype='object')

# %%
#display null values
df[df.isnull().any(axis=1)]
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 0       1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1       3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2       4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3       3173284      6.17     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4       3266500      0.93     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
# ...         ...       ...      ...                  ...                  ...
# 3207    1865681      0.00     0.00  0015-09-25 19:10:00  0015-09-25 19:11:08
# 3209    7155296      0.00     0.00  0015-10-02 19:16:23  0015-10-02 19:18:07
# 3210    7688636      0.00     0.00  0015-10-02 19:18:45  0015-10-02 19:20:08
# 3282    5181950      0.00     0.00  0015-09-23 11:02:55  0015-09-23 13:03:05
# 3286    7661889      0.00     0.00  0015-09-28 11:01:45  0015-09-28 11:03:06
#
#       startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 0            15       17       1.510556     Tue  android  ...               0
# 1            17       19       2.177222     Wed  android  ...               0
# 2            12       16       4.671667     Fri  android  ...               0
# 3            19       21       1.768333     Wed  android  ...               0
# 4            20       21       0.298611     Thu  android  ...               0
# ...         ...      ...            ...     ...      ...  ...             ...
# 3207         19       19       0.018889     Fri      ios  ...               1
# 3209         19       19       0.028889     Fri      ios  ...               1
# 3210         19       19       0.023056     Fri      ios  ...               1
# 3282         11       13       2.002778     Wed      ios  ...               1
# 3286         11       11       0.022500     Mon      ios  ...               1
#
#       facilityType  Mon  Tues  Wed  Thurs  Fri  Sat  Sun  reportedZip
# 0                3    0     1    0      0    0    0    0            0
# 1                3    0     0    1      0    0    0    0            0
# 2                3    0     0    0      0    1    0    0            0
# 3                3    0     0    1      0    0    0    0            0
# 4                3    0     0    0      1    0    0    0            0
# ...            ...  ...   ...  ...    ...  ...  ...  ...          ...
# 3207             3    0     0    0      0    1    0    0            1
# 3209             3    0     0    0      0    1    0    0            1
# 3210             3    0     0    0      0    1    0    0            1
# 3282             2    0     0    1      0    0    0    0            1
# 3286             2    1     0    0      0    0    0    0            1
#
# [1065 rows x 24 columns]

# %%
#number of duplicate entries
print('Duplicate entries found in this dataset = {}.' .format(df.duplicated().sum()))
# Out:
# Duplicate entries found in this dataset = 0.

# %%
#describe data
df[['kwhTotal','dollars','startTime','endTime','chargeTimeHrs','distance']].describe()
# Out:
#           kwhTotal      dollars    startTime      endTime  chargeTimeHrs  \
# count  3395.000000  3395.000000  3395.000000  3395.000000    3395.000000
# mean      5.809629     0.118268    13.743446    16.455965       2.841488
# std       2.892727     0.492562     3.204370     3.406732       1.507472
# min       0.000000     0.000000     0.000000     0.000000       0.012500
# 25%       4.350000     0.000000    11.000000    14.000000       2.110278
# 50%       6.230000     0.000000    13.000000    16.000000       2.808889
# 75%       6.830000     0.000000    17.000000    20.000000       3.544167
# max      23.680000     7.500000    23.000000    23.000000      55.238056
#
#           distance
# count  2330.000000
# mean     18.652378
# std      11.420571
# min       0.856911
# 25%       5.135871
# 50%      21.023826
# 75%      27.285053
# max      43.059292

# %%
#Daily Power Consumption
# create a new column and convert 1 to manufacturing, 2 to office, 3 to R&D and 4 to others in facilityType
df['facilityType'] = df['facilityType'].replace([1,2,3,4],['Manufacturing','Office','R&D','Others'])

# %%
#convert facilityType to Catagorical data
df['facilityType'] = df['facilityType'].replace([1,2,3,4],['Manufacturing','Office','R&D','Others'])

#visualize daily power consumption
plt.figure(figsize=(10,6))
sns.swarmplot(data=df, y='kwhTotal', x='weekday', hue='facilityType')
plt.title('Daily Power Consumption')
plt.xlabel('Days')
plt.ylabel('Power (kWh)')
plt.show()
# Out:
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 59.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 62.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 56.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 62.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Charging Cost with respect to the charging duration
#visualize charging cost w.r.t charging duration
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, y='chargeTimeHrs', x='dollars', hue='weekday')
plt.title('Charging Cost')
plt.xlabel('Charging Cost ($)')
plt.ylabel('Charging Duration (hrs)')
# Out:
# Text(0, 0.5, 'Charging Duration (hrs)')

# %%
#Average charging duration per day
#visualize mean chargeTimeHr per day
plt.figure(figsize=(10,6))
sns.swarmplot(data=df, y='chargeTimeHrs', x='weekday', hue='platform')
plt.title('Charging Duration per day')
plt.xlabel('Day of the week')
plt.ylabel('Charging Duration (hrs)')
# Out:
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adars\OneDrive\Desktop\python\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0, 0.5, 'Charging Duration (hrs)')

# %%
#count the unqiue platform
df['platform'].value_counts() /len(df) * 100
# Out:
# ios        65.802651
# android    34.020619
# web         0.176730
# Name: platform, dtype: float64

# %%
#Installed Charging Stations Share at the Facility
#pie chart of facilityType
plt.figure(figsize=(10,6))
df['facilityType'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Charging Stations share at Facility')
plt.ylabel('')
plt.show()
